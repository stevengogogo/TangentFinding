# %% [markdown]
# Connected to tangentfindingx-J6bZQ1AT-py3.10 (Python 3.10.12)

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt


#test function 
def target_fn(x):
    return jnp.sin(jnp.pi * x * 0.5)

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt


#test function 
def target_fn(x):
    return jnp.sin(jnp.pi * x * 0.5)



def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = fn(x)
    plt.plot(x, y, **kwargs)

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt


#test function 
def target_fn(x):
    return jnp.sin(jnp.pi * x * 0.5)

plot_fn(target_fn, [-1, 1], label='target_fn')


def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = fn(x)
    plt.plot(x, y, **kwargs)
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = fn(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(x):
    return jnp.sin(jnp.pi * x * 0.5)

plot_fn(target_fn, [-1, 1], label='target_fn')

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = fn(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(x):
    return jnp.sin(jnp.pi * x)

plot_fn(target_fn, [-1, 1], label='target_fn')

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = fn(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(x):
    return jnp.sin(jnp.pi * x)

plot_fn(target_fn, [0, 1], label='target_fn')

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = fn(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(x):
    return jnp.sin(jnp.pi * x)

plot_fn(target_fn, [0, 1], label='target_fn')

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = fn(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(x):
    return jnp.sin(jnp.pi * x)

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

fsolve(object_fn, [0., 1.])



plot_fn(target_fn, [0, 1], label='target_fn')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:22
#      19     tan = (target_fn(x) - target_fn(0)) / (x - 0)
#      20     return tan - dfn(x)
# ---> 22 fsolve(object_fn, [0., 1.])
#      26 plot_fn(target_fn, [0, 1], label='target_fn')
#
# File ~/.cache/pypoetry/virtualenvs/tangentfindingx-J6bZQ1AT-py3.10/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:166, in fsolve(func, x0, args, fprime, full_output, col_deriv, xtol, maxfev, band, epsfcn, factor, diag)
#      54 """
#      55 Find the roots of a function.
#      56
#    (...)
#     156
#     157 """
#     158 options = {'col_deriv': col_deriv,
#     159            'xtol': xtol,
#     160            'maxfev': maxfev,
#    (...)
#     163            'factor': factor,
#     164            'diag': diag}
# ...

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = fn(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(x):
    return jnp.sin(jnp.pi * x)

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

fsolve(object_fn, [0., 1.])



plot_fn(target_fn, [0, 1], label='target_fn')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:22
#      19     tan = (target_fn(x) - target_fn(0)) / (x - 0)
#      20     return tan - dfn(x)
# ---> 22 fsolve(object_fn, [0., 1.])
#      26 plot_fn(target_fn, [0, 1], label='target_fn')
#
# File ~/.cache/pypoetry/virtualenvs/tangentfindingx-J6bZQ1AT-py3.10/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:166, in fsolve(func, x0, args, fprime, full_output, col_deriv, xtol, maxfev, band, epsfcn, factor, diag)
#      54 """
#      55 Find the roots of a function.
#      56
#    (...)
#     156
#     157 """
#     158 options = {'col_deriv': col_deriv,
#     159            'xtol': xtol,
#     160            'maxfev': maxfev,
#    (...)
#     163            'factor': factor,
#     164            'diag': diag}
# ...

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = fn(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(x):
    return jnp.sin(jnp.pi * x)

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

fsolve(object_fn, [0., 1.])



plot_fn(target_fn, [0, 1], label='target_fn')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:22
#      19     tan = (target_fn(x) - target_fn(0)) / (x - 0)
#      20     return tan - dfn(x)
# ---> 22 fsolve(object_fn, [0., 1.])
#      26 plot_fn(target_fn, [0, 1], label='target_fn')
#
# File ~/.cache/pypoetry/virtualenvs/tangentfindingx-J6bZQ1AT-py3.10/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:166, in fsolve(func, x0, args, fprime, full_output, col_deriv, xtol, maxfev, band, epsfcn, factor, diag)
#      54 """
#      55 Find the roots of a function.
#      56
#    (...)
#     156
#     157 """
#     158 options = {'col_deriv': col_deriv,
#     159            'xtol': xtol,
#     160            'maxfev': maxfev,
#    (...)
#     163            'factor': factor,
#     164            'diag': diag}
# ...

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = fn(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(x):
    return jnp.sin(jnp.pi * x)

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

fsolve(object_fn, [0., 1.])



plot_fn(target_fn, [0, 1], label='target_fn')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:22
#      19     tan = (target_fn(x) - target_fn(0)) / (x - 0)
#      20     return tan - dfn(x)
# ---> 22 fsolve(object_fn, [0., 1.])
#      26 plot_fn(target_fn, [0, 1], label='target_fn')
#
# File ~/.cache/pypoetry/virtualenvs/tangentfindingx-J6bZQ1AT-py3.10/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:166, in fsolve(func, x0, args, fprime, full_output, col_deriv, xtol, maxfev, band, epsfcn, factor, diag)
#      54 """
#      55 Find the roots of a function.
#      56
#    (...)
#     156
#     157 """
#     158 options = {'col_deriv': col_deriv,
#     159            'xtol': xtol,
#     160            'maxfev': maxfev,
#    (...)
#     163            'factor': factor,
#     164            'diag': diag}
# ...

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = fn(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(x):
    return jnp.sin(jnp.pi * x)

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

fsolve(object_fn, [0., 1.])



plot_fn(target_fn, [0, 1], label='target_fn')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:22
#      19     tan = (target_fn(x) - target_fn(0)) / (x - 0)
#      20     return tan - dfn(x)
# ---> 22 fsolve(object_fn, [0., 1.])
#      26 plot_fn(target_fn, [0, 1], label='target_fn')
#
# File ~/.cache/pypoetry/virtualenvs/tangentfindingx-J6bZQ1AT-py3.10/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:166, in fsolve(func, x0, args, fprime, full_output, col_deriv, xtol, maxfev, band, epsfcn, factor, diag)
#      54 """
#      55 Find the roots of a function.
#      56
#    (...)
#     156
#     157 """
#     158 options = {'col_deriv': col_deriv,
#     159            'xtol': xtol,
#     160            'maxfev': maxfev,
#    (...)
#     163            'factor': factor,
#     164            'diag': diag}
# ...

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = fn(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(x):
    return jnp.sin(jnp.pi * x)

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

fsolve(object_fn, [0., 1.])



plot_fn(target_fn, [0, 1], label='target_fn')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:22
#      19     tan = (target_fn(x) - target_fn(0)) / (x - 0)
#      20     return tan - dfn(x)
# ---> 22 fsolve(object_fn, [0., 1.])
#      26 plot_fn(target_fn, [0, 1], label='target_fn')
#
# File ~/.cache/pypoetry/virtualenvs/tangentfindingx-J6bZQ1AT-py3.10/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:166, in fsolve(func, x0, args, fprime, full_output, col_deriv, xtol, maxfev, band, epsfcn, factor, diag)
#      54 """
#      55 Find the roots of a function.
#      56
#    (...)
#     156
#     157 """
#     158 options = {'col_deriv': col_deriv,
#     159            'xtol': xtol,
#     160            'maxfev': maxfev,
#    (...)
#     163            'factor': factor,
#     164            'diag': diag}
# ...

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = fn(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(x):
    return jnp.sin(jnp.pi * x)

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

fsolve(object_fn, [0., 1.])



plot_fn(target_fn, [0, 1], label='target_fn')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:22
#      19     tan = (target_fn(x) - target_fn(0)) / (x - 0)
#      20     return tan - dfn(x)
# ---> 22 fsolve(object_fn, [0., 1.])
#      26 plot_fn(target_fn, [0, 1], label='target_fn')
#
# File ~/.cache/pypoetry/virtualenvs/tangentfindingx-J6bZQ1AT-py3.10/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:166, in fsolve(func, x0, args, fprime, full_output, col_deriv, xtol, maxfev, band, epsfcn, factor, diag)
#      54 """
#      55 Find the roots of a function.
#      56
#    (...)
#     156
#     157 """
#     158 options = {'col_deriv': col_deriv,
#     159            'xtol': xtol,
#     160            'maxfev': maxfev,
#    (...)
#     163            'factor': factor,
#     164            'diag': diag}
# ...

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = fn(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(x):
    return jnp.sin(jnp.pi * x)

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

fsolve(object_fn, [0., 1.])



plot_fn(target_fn, [0, 1], label='target_fn')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:22
#      19     tan = (target_fn(x) - target_fn(0)) / (x - 0)
#      20     return tan - dfn(x)
# ---> 22 fsolve(object_fn, [0., 1.])
#      26 plot_fn(target_fn, [0, 1], label='target_fn')
#
# File ~/.cache/pypoetry/virtualenvs/tangentfindingx-J6bZQ1AT-py3.10/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:166, in fsolve(func, x0, args, fprime, full_output, col_deriv, xtol, maxfev, band, epsfcn, factor, diag)
#      54 """
#      55 Find the roots of a function.
#      56
#    (...)
#     156
#     157 """
#     158 options = {'col_deriv': col_deriv,
#     159            'xtol': xtol,
#     160            'maxfev': maxfev,
#    (...)
#     163            'factor': factor,
#     164            'diag': diag}
# ...

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = fn(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(x):
    return jnp.sin(jnp.pi * x)

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

fsolve(object_fn, [0., 1.])



plot_fn(target_fn, [0, 1], label='target_fn')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:22
#      19     tan = (target_fn(x) - target_fn(0)) / (x - 0)
#      20     return tan - dfn(x)
# ---> 22 fsolve(object_fn, [0., 1.])
#      26 plot_fn(target_fn, [0, 1], label='target_fn')
#
# File ~/.cache/pypoetry/virtualenvs/tangentfindingx-J6bZQ1AT-py3.10/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:166, in fsolve(func, x0, args, fprime, full_output, col_deriv, xtol, maxfev, band, epsfcn, factor, diag)
#      54 """
#      55 Find the roots of a function.
#      56
#    (...)
#     156
#     157 """
#     158 options = {'col_deriv': col_deriv,
#     159            'xtol': xtol,
#     160            'maxfev': maxfev,
#    (...)
#     163            'factor': factor,
#     164            'diag': diag}
# ...

# %%
dfn(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 dfn(1)
#
#     [... skipping hidden 4 frame]
#
# File ~/.cache/pypoetry/virtualenvs/tangentfindingx-J6bZQ1AT-py3.10/lib/python3.10/site-packages/jax/_src/api.py:730, in _check_input_dtype_revderiv(name, holomorphic, allow_int, x)
#     726 if (dtypes.issubdtype(aval.dtype, dtypes.extended) or
#     727     dtypes.issubdtype(aval.dtype, np.integer) or
#     728     dtypes.issubdtype(aval.dtype, np.bool_)):
#     729   if not allow_int:
# --> 730     raise TypeError(f"{name} requires real- or complex-valued inputs (input dtype "
#     731                     f"that is a sub-dtype of np.inexact), but got {aval.dtype.name}. "
#     732                     "If you want to use Boolean- or integer-valued inputs, use vjp "
#     733                     "or set allow_int to True.")
# ...

# %%
dfn(1.)
# Out:
# Array(-3.1415927, dtype=float32, weak_type=True)

# %%
object_fn(0.)
# Out:
# Array(nan, dtype=float32, weak_type=True)

# %%
object_fn(1.)
# Out:
# Array(3.1415927, dtype=float32, weak_type=True)

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = fn(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(x):
    return jnp.sin(jnp.pi * x)

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

fsolve(object_fn, [1e-6, 1.])



plot_fn(target_fn, [0, 1], label='target_fn')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:22
#      19     tan = (target_fn(x) - target_fn(0)) / (x - 0)
#      20     return tan - dfn(x)
# ---> 22 fsolve(object_fn, [1e-6, 1.])
#      26 plot_fn(target_fn, [0, 1], label='target_fn')
#
# File ~/.cache/pypoetry/virtualenvs/tangentfindingx-J6bZQ1AT-py3.10/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:166, in fsolve(func, x0, args, fprime, full_output, col_deriv, xtol, maxfev, band, epsfcn, factor, diag)
#      54 """
#      55 Find the roots of a function.
#      56
#    (...)
#     156
#     157 """
#     158 options = {'col_deriv': col_deriv,
#     159            'xtol': xtol,
#     160            'maxfev': maxfev,
#    (...)
#     163            'factor': factor,
#     164            'diag': diag}
# ...

# %%
object_fn(0.1)
# Out:
# Array(0.1023376, dtype=float32, weak_type=True)

# %%
object_fn(0.5)
# Out:
# Array(2.0000002, dtype=float32, weak_type=True)

# %%
object_fn(0.7)
# Out:
# Array(3.0023203, dtype=float32, weak_type=True)

# %%
object_fn(0.3)
# Out:
# Array(0.8501415, dtype=float32, weak_type=True)

# %%
object_fn(0.1)
# Out:
# Array(0.1023376, dtype=float32, weak_type=True)

# %%
object_fn(0.01)
# Out:
# Array(0.00103354, dtype=float32, weak_type=True)

# %%
object_fn(0.00001)
# Out:
# Array(0., dtype=float32, weak_type=True)

# %%
object_fn(0.0001)
# Out:
# Array(2.3841858e-07, dtype=float32, weak_type=True)

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = fn(x)
    plt.plot(x, y, **kwargs)

#test function 
def Frac_flow_original(u):
    swc = 0.0
    sor = 0.0
    kro_0 = 1.0
    krw_0 = 1.0
    no = 2
    nw = 2
    mu_r = 1
    Ng = 2.4 
    S =  (u-sor) /  (1-sor-swc)
    kro = kro_0 S**no
    krw = krw_0* (1-S)**nw
    M = krw/kro/mu_r
    f1 = 1 / (1 + M)
    f2 = (Ng*M*kro) / (1 + M)
    return  f1

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

fsolve(object_fn, [1e-6, 1.])



plot_fn(target_fn, [0, 1], label='target_fn')
# Out:
#   Cell In[30], line 23
#     kro = kro_0 S**no
#                 ^
# SyntaxError: invalid syntax

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = fn(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(u):
    swc = 0.0
    sor = 0.0
    kro_0 = 1.0
    krw_0 = 1.0
    no = 2
    nw = 2
    mu_r = 1
    Ng = 2.4 
    S =  (u-sor) /  (1-sor-swc)
    kro = kro_0 * S**no
    krw = krw_0* (1-S)**nw
    M = krw/kro/mu_r
    f1 = 1 / (1 + M)
    f2 = (Ng*M*kro) / (1 + M)
    return  f1

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

fsolve(object_fn, [1e-6, 1.])



plot_fn(target_fn, [0, 1], label='target_fn')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:36
#      33     tan = (target_fn(x) - target_fn(0)) / (x - 0)
#      34     return tan - dfn(x)
# ---> 36 fsolve(object_fn, [1e-6, 1.])
#      40 plot_fn(target_fn, [0, 1], label='target_fn')
#
# File ~/.cache/pypoetry/virtualenvs/tangentfindingx-J6bZQ1AT-py3.10/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:166, in fsolve(func, x0, args, fprime, full_output, col_deriv, xtol, maxfev, band, epsfcn, factor, diag)
#      54 """
#      55 Find the roots of a function.
#      56
#    (...)
#     156
#     157 """
#     158 options = {'col_deriv': col_deriv,
#     159            'xtol': xtol,
#     160            'maxfev': maxfev,
#    (...)
#     163            'factor': factor,
#     164            'diag': diag}
# ...

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = fn(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(u):
    swc = 0.0
    sor = 0.0
    kro_0 = 1.0
    krw_0 = 1.0
    no = 2
    nw = 2
    mu_r = 1
    Ng = 2.4 
    S =  (u-sor) /  (1-sor-swc)
    kro = kro_0 * S**no
    krw = krw_0* (1-S)**nw
    print(krw)
    M = krw/kro/mu_r
    f1 = 1 / (1 + M)
    f2 = (Ng*M*kro) / (1 + M)
    return  f1

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

fsolve(object_fn, [1e-6, 1.])



plot_fn(target_fn, [0, 1], label='target_fn')
# Out:
# [0.999998 0.      ]
# 1.0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:37
#      34     tan = (target_fn(x) - target_fn(0)) / (x - 0)
#      35     return tan - dfn(x)
# ---> 37 fsolve(object_fn, [1e-6, 1.])
#      41 plot_fn(target_fn, [0, 1], label='target_fn')
#
# File ~/.cache/pypoetry/virtualenvs/tangentfindingx-J6bZQ1AT-py3.10/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:166, in fsolve(func, x0, args, fprime, full_output, col_deriv, xtol, maxfev, band, epsfcn, factor, diag)
#      54 """
#      55 Find the roots of a function.
#      56
#    (...)
#     156
#     157 """
#     158 options = {'col_deriv': col_deriv,
#     159            'xtol': xtol,
#     160            'maxfev': maxfev,
#    (...)
#     163            'factor': factor,
# ...

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = fn(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(u):
    swc = 0.0
    sor = 0.0
    kro_0 = 1.0
    krw_0 = 1.0
    no = 2
    nw = 2
    mu_r = 1
    Ng = 2.4 
    S =  (u-sor) /  (1-sor-swc)
    kro = kro_0 * S**no
    krw = krw_0* (1-S)**nw
    M = krw/kro/mu_r
    f1 = 1 / (1 + M)
    f2 = (Ng*M*kro) / (1 + M)
    return  f1

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

#fsolve(object_fn, [1e-6, 1.])



plot_fn(target_fn, [0, 1], label='target_fn')

# %%
target_fn(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 target_fn(x)
#
# NameError: name 'x' is not defined

# %%
target_fn(0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 target_fn(0)
#
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:25
#      23 kro = kro_0 * S**no
#      24 krw = krw_0* (1-S)**nw
# ---> 25 M = krw/kro/mu_r
#      26 f1 = 1 / (1 + M)
#      27 f2 = (Ng*M*kro) / (1 + M)
#
# ZeroDivisionError: float division by zero

# %%
target_fn(0.)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 target_fn(0.)
#
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:25
#      23 kro = kro_0 * S**no
#      24 krw = krw_0* (1-S)**nw
# ---> 25 M = krw/kro/mu_r
#      26 f1 = 1 / (1 + M)
#      27 f2 = (Ng*M*kro) / (1 + M)
#
# ZeroDivisionError: float division by zero

# %%
target_fn(0.0001)
# Out:
# 1.0002000199999996e-08

# %%
target_fn(1.)
# Out:
# 1.0

# %%
target_fn(0.000001)
# Out:
# 1.000002000002e-12

# %%
target_fn(0.)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 target_fn(0.)
#
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:25
#      23 kro = kro_0 * S**no
#      24 krw = krw_0* (1-S)**nw
# ---> 25 M = krw/kro/mu_r
#      26 f1 = 1 / (1 + M)
#      27 f2 = (Ng*M*kro) / (1 + M)
#
# ZeroDivisionError: float division by zero

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = fn(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(u):
    swc = 0.0
    sor = 0.0
    kro_0 = 1.0
    krw_0 = 1.0
    no = 2
    nw = 2
    mu_r = 1
    Ng = 2.4 
    S =  (u-sor) /  (1-sor-swc)
    kro = kro_0 * S**no
    krw = krw_0* (1-S)**nw

    M = krw/(kro+1e-7)/mu_r
    f1 = 1 / (1 + M)
    f2 = (Ng*M*kro) / (1 + M)
    return  f1

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

#fsolve(object_fn, [1e-6, 1.])



plot_fn(target_fn, [0, 1], label='target_fn')

# %%
target_fn(0.)
# Out:
# 9.9999990000001e-08

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = fn(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(u):
    swc = 0.0
    sor = 0.0
    kro_0 = 1.0
    krw_0 = 1.0
    no = 2
    nw = 2
    mu_r = 1
    Ng = 2.4 
    S =  (u-sor) /  (1-sor-swc)
    kro = kro_0 * S**no
    krw = krw_0* (1-S)**nw

    M = jax.lax.cond(u!=0, lambda u: krw/(kro)/mu_r, lambda u:0)
    f1 = 1 / (1 + M)
    f2 = (Ng*M*kro) / (1 + M)
    return  f1

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

#fsolve(object_fn, [1e-6, 1.])



plot_fn(target_fn, [0, 1], label='target_fn')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:41
#      35     return tan - dfn(x)
#      37 #fsolve(object_fn, [1e-6, 1.])
# ---> 41 plot_fn(target_fn, [0, 1], label='target_fn')
#
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:9
#       7 def plot_fn(fn, x_range, ngrid=1000,**kwargs):
#       8     x = jnp.linspace(x_range[0], x_range[1], 1000)
# ----> 9     y = fn(x)
#      10     plt.plot(x, y, **kwargs)
#
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:26
#      23 kro = kro_0 * S**no
#      24 krw = krw_0* (1-S)**nw
# ---> 26 M = jax.lax.cond(u!=0, lambda u: krw/(kro)/mu_r, lambda u:0)
#      27 f1 = 1 / (1 + M)
#      28 f2 = (Ng*M*kro) / (1 + M)
#
#     [... skipping hidden 2 frame]
#
# ...

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = jax.vmap(fn)(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(u):
    swc = 0.0
    sor = 0.0
    kro_0 = 1.0
    krw_0 = 1.0
    no = 2
    nw = 2
    mu_r = 1
    Ng = 2.4 
    S =  (u-sor) /  (1-sor-swc)
    kro = kro_0 * S**no
    krw = krw_0* (1-S)**nw

    M = jax.lax.cond(u!=0, lambda u: krw/(kro)/mu_r, lambda u:0)
    f1 = 1 / (1 + M)
    f2 = (Ng*M*kro) / (1 + M)
    return  f1

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

#fsolve(object_fn, [1e-6, 1.])



plot_fn(target_fn, [0, 1], label='target_fn')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:41
#      35     return tan - dfn(x)
#      37 #fsolve(object_fn, [1e-6, 1.])
# ---> 41 plot_fn(target_fn, [0, 1], label='target_fn')
#
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:9
#       7 def plot_fn(fn, x_range, ngrid=1000,**kwargs):
#       8     x = jnp.linspace(x_range[0], x_range[1], 1000)
# ----> 9     y = jax.vmap(fn)(x)
#      10     plt.plot(x, y, **kwargs)
#
#     [... skipping hidden 3 frame]
#
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:26
#      23 kro = kro_0 * S**no
#      24 krw = krw_0* (1-S)**nw
# ---> 26 M = jax.lax.cond(u!=0, lambda u: krw/(kro)/mu_r, lambda u:0)
#      27 f1 = 1 / (1 + M)
# ...

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = jax.vmap(fn)(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(u):
    swc = 0.0
    sor = 0.0
    kro_0 = 1.0
    krw_0 = 1.0
    no = 2
    nw = 2
    mu_r = 1
    Ng = 2.4 
    S =  (u-sor) /  (1-sor-swc)
    kro = kro_0 * S**no
    krw = krw_0* (1-S)**nw

    M = jax.lax.cond(u!=0, lambda _: krw/(kro)/mu_r, lambda _:0)
    f1 = 1 / (1 + M)
    f2 = (Ng*M*kro) / (1 + M)
    return  f1

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

#fsolve(object_fn, [1e-6, 1.])



plot_fn(target_fn, [0, 1], label='target_fn')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:41
#      35     return tan - dfn(x)
#      37 #fsolve(object_fn, [1e-6, 1.])
# ---> 41 plot_fn(target_fn, [0, 1], label='target_fn')
#
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:9
#       7 def plot_fn(fn, x_range, ngrid=1000,**kwargs):
#       8     x = jnp.linspace(x_range[0], x_range[1], 1000)
# ----> 9     y = jax.vmap(fn)(x)
#      10     plt.plot(x, y, **kwargs)
#
#     [... skipping hidden 3 frame]
#
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:26
#      23 kro = kro_0 * S**no
#      24 krw = krw_0* (1-S)**nw
# ---> 26 M = jax.lax.cond(u!=0, lambda _: krw/(kro)/mu_r, lambda _:0)
#      27 f1 = 1 / (1 + M)
# ...

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = jax.vmap(fn)(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(u):
    swc = 0.0
    sor = 0.0
    kro_0 = 1.0
    krw_0 = 1.0
    no = 2
    nw = 2
    mu_r = 1
    Ng = 2.4 
    S =  (u-sor) /  (1-sor-swc)
    kro = kro_0 * S**no
    krw = krw_0* (1-S)**nw

    M = jax.lax.cond(u!=0, lambda u: krw/(kro)/mu_r, lambda u:0, u)
    f1 = 1 / (1 + M)
    f2 = (Ng*M*kro) / (1 + M)
    return  f1

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

#fsolve(object_fn, [1e-6, 1.])



plot_fn(target_fn, [0, 1], label='target_fn')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:41
#      35     return tan - dfn(x)
#      37 #fsolve(object_fn, [1e-6, 1.])
# ---> 41 plot_fn(target_fn, [0, 1], label='target_fn')
#
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:9
#       7 def plot_fn(fn, x_range, ngrid=1000,**kwargs):
#       8     x = jnp.linspace(x_range[0], x_range[1], 1000)
# ----> 9     y = jax.vmap(fn)(x)
#      10     plt.plot(x, y, **kwargs)
#
#     [... skipping hidden 3 frame]
#
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:26
#      23 kro = kro_0 * S**no
#      24 krw = krw_0* (1-S)**nw
# ---> 26 M = jax.lax.cond(u!=0, lambda u: krw/(kro)/mu_r, lambda u:0, u)
#      27 f1 = 1 / (1 + M)
# ...

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = jax.vmap(fn)(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(u):
    swc = 0.0
    sor = 0.0
    kro_0 = 1.0
    krw_0 = 1.0
    no = 2
    nw = 2
    mu_r = 1
    Ng = 2.4 
    S =  (u-sor) /  (1-sor-swc)
    kro = kro_0 * S**no
    krw = krw_0* (1-S)**nw

    M = jax.lax.cond(u!=0, lambda u: krw/(kro)/mu_r, lambda u:0., u)
    f1 = 1 / (1 + M)
    f2 = (Ng*M*kro) / (1 + M)
    return  f1

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

#fsolve(object_fn, [1e-6, 1.])



plot_fn(target_fn, [0, 1], label='target_fn')

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = jax.vmap(fn)(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(u):
    swc = 0.0
    sor = 0.0
    kro_0 = 1.0
    krw_0 = 1.0
    no = 2
    nw = 2
    mu_r = 1
    Ng = 2.4 
    S =  (u-sor) /  (1-sor-swc)
    kro = kro_0 * S**no
    krw = krw_0* (1-S)**nw

    M = jax.lax.cond(u!=0, lambda u: krw/(kro)/mu_r, lambda u:jnp.inf, u)
    f1 = 1 / (1 + M)
    f2 = (Ng*M*kro) / (1 + M)
    return  f1

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

#fsolve(object_fn, [1e-6, 1.])



plot_fn(target_fn, [0, 1], label='target_fn')

# %%
target_fn(0.)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 target_fn(0.)
#
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:26
#      23 kro = kro_0 * S**no
#      24 krw = krw_0* (1-S)**nw
# ---> 26 M = jax.lax.cond(u!=0, lambda u: krw/(kro)/mu_r, lambda u:jnp.inf, u)
#      27 f1 = 1 / (1 + M)
#      28 f2 = (Ng*M*kro) / (1 + M)
#
#     [... skipping hidden 12 frame]
#
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:26
#      23 kro = kro_0 * S**no
#      24 krw = krw_0* (1-S)**nw
# ---> 26 M = jax.lax.cond(u!=0, lambda u: krw/(kro)/mu_r, lambda u:jnp.inf, u)
#      27 f1 = 1 / (1 + M)
#      28 f2 = (Ng*M*kro) / (1 + M)
#
# ZeroDivisionError: float division by zero

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = jax.vmap(fn)(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(u):
    swc = 0.0
    sor = 0.0
    kro_0 = 1.0
    krw_0 = 1.0
    no = 2
    nw = 2
    mu_r = 1
    Ng = 2.4 
    S =  (u-sor) /  (1-sor-swc)
    kro = kro_0 * S**no
    krw = krw_0* (1-S)**nw

    M = jax.lax.cond(u==0, lambda u: krw/(kro)/mu_r, lambda u:jnp.inf, u)
    f1 = 1 / (1 + M)
    f2 = (Ng*M*kro) / (1 + M)
    return  f1

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

#fsolve(object_fn, [1e-6, 1.])



plot_fn(target_fn, [0, 1], label='target_fn')

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = jax.vmap(fn)(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(u):
    swc = 0.0
    sor = 0.0
    kro_0 = 1.0
    krw_0 = 1.0
    no = 2
    nw = 2
    mu_r = 1
    Ng = 2.4 
    S =  (u-sor) /  (1-sor-swc)
    kro = kro_0 * S**no
    krw = krw_0* (1-S)**nw

    M = jax.lax.cond(u!=0, lambda u: krw/(kro)/mu_r, lambda u:jnp.inf, u)
    f1 = 1 / (1 + M)
    f2 = (Ng*M*kro) / (1 + M)
    return  f1

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

#fsolve(object_fn, [1e-6, 1.])



plot_fn(target_fn, [0, 1], label='target_fn')

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = jax.vmap(fn)(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(u):
    swc = 0.0
    sor = 0.0
    kro_0 = 1.0
    krw_0 = 1.0
    no = 2
    nw = 2
    mu_r = 1
    Ng = 2.4 
    S =  (u-sor) /  (1-sor-swc)
    kro = kro_0 * S**no
    krw = krw_0* (1-S)**nw

    M = jax.lax.cond(u!=0, lambda u: krw/(kro)/mu_r, lambda u:jnp.inf, u)
    f1 = 1 / (1 + M)
    f2 = (Ng*M*kro) / (1 + M)
    return  f1

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

#fsolve(object_fn, [1e-6, 1.])



plot_fn(target_fn, [0, 1], label='target_fn')

# %%
target_fn(0.000001)
# Out:
# Array(1.000002e-12, dtype=float32, weak_type=True)

# %%
target_fn(0.)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 target_fn(0.)
#
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:26
#      23 kro = kro_0 * S**no
#      24 krw = krw_0* (1-S)**nw
# ---> 26 M = jax.lax.cond(u!=0, lambda u: krw/(kro)/mu_r, lambda u:jnp.inf, u)
#      27 f1 = 1 / (1 + M)
#      28 f2 = (Ng*M*kro) / (1 + M)
#
#     [... skipping hidden 12 frame]
#
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:26
#      23 kro = kro_0 * S**no
#      24 krw = krw_0* (1-S)**nw
# ---> 26 M = jax.lax.cond(u!=0, lambda u: krw/(kro)/mu_r, lambda u:jnp.inf, u)
#      27 f1 = 1 / (1 + M)
#      28 f2 = (Ng*M*kro) / (1 + M)
#
# ZeroDivisionError: float division by zero

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = jax.vmap(fn)(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(u):
    swc = 0.0
    sor = 0.0
    kro_0 = 1.0
    krw_0 = 1.0
    no = 2
    nw = 2
    mu_r = 1
    Ng = 2.4 
    S =  (u-sor) /  (1-sor-swc)
    kro = kro_0 * S**no
    krw = krw_0* (1-S)**nw

    M = jax.lax.cond(u!=0, lambda u: krw/(kro)/mu_r, lambda u:2., u)
    f1 = 1 / (1 + M)
    f2 = (Ng*M*kro) / (1 + M)
    return  f1

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

#fsolve(object_fn, [1e-6, 1.])



plot_fn(target_fn, [0, 1], label='target_fn')

# %%
target_fn(0.)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 target_fn(0.)
#
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:26
#      23 kro = kro_0 * S**no
#      24 krw = krw_0* (1-S)**nw
# ---> 26 M = jax.lax.cond(u!=0, lambda u: krw/(kro)/mu_r, lambda u:2., u)
#      27 f1 = 1 / (1 + M)
#      28 f2 = (Ng*M*kro) / (1 + M)
#
#     [... skipping hidden 12 frame]
#
# File /home/stevenchiu/Documents/github/TangentFindingx/examples/tangentfinding_scratch.py:26
#      23 kro = kro_0 * S**no
#      24 krw = krw_0* (1-S)**nw
# ---> 26 M = jax.lax.cond(u!=0, lambda u: krw/(kro)/mu_r, lambda u:2., u)
#      27 f1 = 1 / (1 + M)
#      28 f2 = (Ng*M*kro) / (1 + M)
#
# ZeroDivisionError: float division by zero

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = jax.vmap(fn)(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(u):
    swc = 0.0
    sor = 0.0
    kro_0 = 1.0
    krw_0 = 1.0
    no = 2
    nw = 2
    mu_r = 1
    Ng = 2.4 
    S =  (u-sor) /  (1-sor-swc)
    kro = kro_0 * S**no
    krw = krw_0* (1-S)**nw

    M = jax.lax.cond(u==0, lambda u:0., lambda u: krw/(kro)/mu_r, u)
    f1 = 1 / (1 + M)
    f2 = (Ng*M*kro) / (1 + M)
    return  f1

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

#fsolve(object_fn, [1e-6, 1.])



plot_fn(target_fn, [0, 1], label='target_fn')

# %%
import jax 
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def plot_fn(fn, x_range, ngrid=1000,**kwargs):
    x = jnp.linspace(x_range[0], x_range[1], 1000)
    y = jax.vmap(fn)(x)
    plt.plot(x, y, **kwargs)

#test function 
def target_fn(u):
    swc = 0.0
    sor = 0.0
    kro_0 = 1.0
    krw_0 = 1.0
    no = 2
    nw = 2
    mu_r = 1
    Ng = 2.4 
    S =  (u-sor) /  (1-sor-swc)
    kro = kro_0 * S**no
    krw = krw_0* (1-S)**nw

    M = jax.lax.cond(u==0, lambda u:jnp.inf, lambda u: krw/(kro)/mu_r, u)
    f1 = 1 / (1 + M)
    f2 = (Ng*M*kro) / (1 + M)
    return  f1

dfn = jax.grad(target_fn)

def object_fn(x):
    tan = (target_fn(x) - target_fn(0)) / (x - 0)
    return tan - dfn(x)

#fsolve(object_fn, [1e-6, 1.])



plot_fn(target_fn, [0, 1], label='target_fn')
